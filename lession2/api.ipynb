# %%
import requests

api_url = "https://public.richdataservices.com/rds/api/query/covid19/jhu_country/select?cols=date_stamp,cnt_confirmed,cnt_death,cnt_recovered&where=(iso3166_1=US)&format=amcharts&limit=5000"

reponse = requests.get(api_url);

print(reponse.json());
# Out:
# {'dataProvider': [{'date_stamp': '2020-01-22', 'cnt_confirmed': 1, 'cnt_death': 0, 'cnt_recovered': 0}, {'date_stamp': '2020-01-23', 'cnt_confirmed': 1, 'cnt_death': 0, 'cnt_recovered': 0}, {'date_stamp': '2020-01-24', 'cnt_confirmed': 2, 'cnt_death': 0, 'cnt_recovered': 0}, {'date_stamp': '2020-01-25', 'cnt_confirmed': 2, 'cnt_death': 0, 'cnt_recovered': 0}, {'date_stamp': '2020-01-26', 'cnt_confirmed': 5, 'cnt_death': 0, 'cnt_recovered': 0}, {'date_stamp': '2020-01-27', 'cnt_confirmed': 5, 'cnt_death': 0, 'cnt_recovered': 0}, {'date_stamp': '2020-01-28', 'cnt_confirmed': 5, 'cnt_death': 0, 'cnt_recovered': 0}, {'date_stamp': '2020-01-29', 'cnt_confirmed': 5, 'cnt_death': 0, 'cnt_recovered': 0}, {'date_stamp': '2020-01-30', 'cnt_confirmed': 5, 'cnt_death': 0, 'cnt_recovered': 0}, {'date_stamp': '2020-01-31', 'cnt_confirmed': 6, 'cnt_death': 0, 'cnt_recovered': 0}, {'date_stamp': '2020-02-01', 'cnt_confirmed': 8, 'cnt_death': 0, 'cnt_recovered': 0}, {'date_stamp': '2020-02-02', 'cnt_
# ...
